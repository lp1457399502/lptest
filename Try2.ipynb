# %% [markdown]
# # 初めてのノートブック
#
# **書きましょう**

# %%
#計算する


2*(3+4)
# Out:
# 14

# %% [markdown]
# *出力してみましょう＊
#
#
#
# ```
# # First value:1
# ```
#
# ```
# # これはコードとして書式設定されます
# ```

# %%
'''

値を出力する
'''
print ('First value:', 1)
# Out:
# First value: 1

# %% [markdown]
# **`sort`の関数を呼び出す**
# 1. 以下のリストを作る
#
# ```
# Number = [4,3,2,1]
# ```
# 2. `sort()`の関数を使って、リストをソートする。
# 3. `print`を使って、出力する。

# %%
Numbers = [4,3,2,1]
Numbers.sort()
print (Numbers)
# Out:
# [1, 2, 3, 4]
